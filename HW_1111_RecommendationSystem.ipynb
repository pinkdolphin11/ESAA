# %% [markdown]
# <a href="https://colab.research.google.com/github/pinkdolphin11/ESAA/blob/main/HW_1111_RecommendationSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chap 9. 추천 시스템

# %% [markdown]
# ## 01. 추천 시스템의 개요와 배경

# %% [markdown]
# ### 추천 시스템의 개요

# %% [markdown]
# * 지금은 추천 시스템의 전성기
#
# * 하나의 콘텐츠를 선택했을 때, 선택된 콘텐츠와 연관된 추천 콘텐츠가 얼마나 사용자의 관심을 끄는지가 전자상거래 플랫폼, 콘텐츠 포털 등 다양한 사이트의 평판을 좌우하는 중요한 요소로 작용하고 있다.
#
# * 사용자 스스로도 몰랐던 취향을 시스템이 발견하는 것이 추천 시스템의 묘미 : 좋은 추천 시스템을 접한 사용자는 해당 사이트를 더 강하게 신뢰하게 되어 더 많은 추천 콘텐츠를 선텍함 -> 더 많은 데이터가 추천 시스템에 축적되면서 더욱 정확한 추천 결과를 얻을 수 있는 선순환 시스템 구축

# %% [markdown]
# ### 온라인 스토어의 필수 요소, 추천 시스템

# %% [markdown]
# * 한정된 시간 안에 너무 많은 상품 중 원하는 것을 선택해야 하는 사용자의 압박감을 타계해 줌
#
# * 추천 시스템 구성에 사용될 수 있는 데이터
#
#   * 사용자가 구매한 상품
#   * 사용자가 둘러보거나 장바구니에 넣은 상품
#   * 사용자의 제품 평가
#   * 사용자가 스스로 작성한 자신의 취향
#   * 사용자가 클릭한 상품

# %% [markdown]
# ### 추천 시스템의 유형

# %% [markdown]
# * 콘텐츠 기반 필터링(Content based filtering)
#
# * 협업 필터링(Collaborative Filtering)
#
#   * 최근접 이웃(Nearest Neighbor) 협업 필터링(아마존에서는 이 알고리즘 사용)
#
#   * 잠재 요인(Latent Factor) 협업 필터링 : 행렬 분해(Matrix Factorization) 기법 이용 - 넷플릭스 추천 시스템 경연대회 우승으로 현재 대부분의 온라인 스토어에서 사용하고 있음

# %% [markdown]
# ## 02. 콘텐츠 기반 필터링 추천 시스템

# %% [markdown]
# * 사용자가 특정한 아이템을 매우 선호하는 경우, 그 아이템과 비슷한 콘텐츠를 가진 다른 아이템을 추천
#
#   ex> 사용자가 특정 영화에 높은 평점을 줬다면, 그 영화의 장르, 출연 배우, 감독, 영화 키워드 등의 콘텐츠와 유사한 다른 영화 추천

# %% [markdown]
# ## 03. 최근접 이웃 협업 필터링

# %% [markdown]
# * 사용자가 아이템에 매긴 평점 정보나 상품 구매 이력 등 사용자 행동 양식(User Behavior)을 기반으로 추천 수행
#
# * 사용자가 평가한 다른 아이템을 기반으로 사용자가 평가하지 않은 아이템의 예측 평가 도출
#
# * 사용자-아이템 평점 매트릭스
#
#  * 2가지 방식(최근접 이웃, 잠재 요인) 모두 사용자-아이템 평점 행렬 데이터에만 의지해 추천 수행
#
#  * Row : 개별 사용자, Column : 개별 아이템, 값 : 평점
#
#  * 다차원 행렬, 희소 행렬
#
# 1. 최근접 이웃 협업 필터링(메모리 협업 필터링)
#
#   * 사용자 기반(User-User) : 특정 사용자와 유사한 다른 사용자를 TOP-N으로 선정해(유사도 Similarity TOP-N 사용자) 이 사용자들이 좋아하는 아이템을 추천(당신과 비슷한 고객들이 다음 상품도 구매했습니다.)
#
#   * 아이템 기반(Item-Item) : 아이템이 가지는 속성과 상관없이 사용자들이 그 아이템을 좋아하는지/싫어하는지의 평가 척도가 유사한 아이템을 추천(이 상품을 선택한 다른 고객들은 다음 상품도 구매했습니다.)
#
#   * 아이템 기반 협업 필터링의 정확도가 더 높다.

# %% [markdown]
# ## 04. 잠재 요인 협업 필터링

# %% [markdown]
# ### 잠재 요인 협업 필터링의 이해

# %% [markdown]
# * 사용자-아이템 평점 행렬 데이터만을 이용해 '잠재 요인'을 도출하는 것
#
# * 잠재 요인이 무엇인지는 명확히 정의할 수 없음. 하지만 이를 기반으로 다차원 희소 행렬인 사용자-아이템 행렬 데이터를 저차원 밀집 행렬의 사용자-잠재 요인 행렬과 아이템-잠재 요인 전치 행렬(잠재 요인-아이템 행렬)로 분해 -> 두 행렬의 내적을 통해 새로운 예측 사용자-아이템 평점 행렬 데이터를 만들어서 사용자가 아직 평점을 부여하지 않은 아이템에 대한 예측 평점 생성
#
#   ex> 영화 평점 기반 사용자-아이템 평점 행렬 데이터 잠재 요인 : 영화가 가지는 장르별 특성 선호도로 가정할 수 있음. 이 경우 사용자-잠재 요인 행렬은 사용자의 영화 장르에 대한 선호도로, 아이템-잠재 요인 행렬은 영화의 장르별 특성값으로 정의할 수 있음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 행렬 분해의 이해

# %% [markdown]
# * 다차원의 매트릭스를 저차원 매트릭스로 분해하는 기법
#
# * SVD(Singular Vector Decomposition)
#
# * NMF(Non-Negative Matrix Factorization)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * R = P * Q.T
#
#   * M : 총 사용자 수
#   * N : 총 아이템 수
#   * K : 잠재 요인의 차원 수
#   * R : M X N 차원의 사용자 - 아이템 평점 행렬
#   * P : 사용자와 잠재 요인과의 관계 값을 가지는 M X K 차원의 사용자-잠재 요인 행렬
#   * Q : 아이템과 잠재 요인과의 관계 값을 가지는 N X K 차원의 아이템-잠재 요인 행렬
#   * Q.T : Q의 전치 행렬
#
# * R 행렬의 u행 사용자와 i열 아이템 위치에 있는 평점 데이터를 $r(u, i)$라고 하면
#
#   $r(u, i) = p_{u} * q_{i}^{t}$
#
# * 사용자-아이템 평점 행렬의 미정 값을 포함한 모든 평점 값은 행렬 분해를 통해 얻어진 P 행렬과 Q.T 행렬의 내적을 통해 예측 평점으로 다시 계산 가능
#
#   $R \cong \hat{R} = P * Q.T$
#
# * SVD는 NaN 값이 없는 행렬에만 적용할 수 있으므로 확률적 경사 하강법이나 ALS 방식을 이용해 SVD 수행

# %% [markdown]
# ### 확률적 경사 하강법을 이용한 행렬 분해

# %% [markdown]
# * P와 Q 행렬로 계산된 예측 R 행렬 값이 실제 R 행렬 값과 가장 최소의 오류를 가질 수 있도록 반복적인 비용 함수 최적화를 통해 P, Q 유추
#
# * 과정
#
#   1. P, Q를 임의의 값을 가진 행렬로 설정
#   2. P와 Q.T 값을 곱해 예측 R 행렬을 계산하고 예측 R 행렬과 실제 R 행렬에 해당하는 오류 값 계산
#   3. 이 오류 값을 최소화할 수 있도록 P, Q 행렬을 적절한 값으로 각각 업데이트
#   4. 만족할 만한 오류 값을 가질 때까지 2, 3번을 반복하면서 P, Q를 업데이트해 근사화
#
# * 비용 함수식
#
#   $min\Sigma(r(u,i)-p_{u}q_{i}^{t})^2+λ(||q_{i}||^2+||p_{u}||^2)$

# %%
# SGD 행렬 분해

import numpy as np

## 원본 행렬 R 생성, 분해 행렬 P와 Q 초기화, 잠재 요인 차원 K=3
R = np.array([[4,np.NaN,np.NaN,2,np.NaN],[np.NaN,5,np.NaN,3,1],[np.NaN,np.NaN,3,4,4],[5,2,1,2,np.NaN]])
num_users, num_items = R.shape
K=3

## P와 Q 행렬의 크기를 지정하고 정규 분포를 가진 임의의 값으로 입력
np.random.seed(1)
P = np.random.normal(scale=1./K,size=(num_users,K))
Q = np.random.normal(scale=1./K,size=(num_items,K))

# %%
from numpy.core.numeric import full_like
# 실제 R 행렬과 예측 행렬의 오차를 구하는 함수 정의

from sklearn.metrics import mean_squared_error

def get_rmse(R,P,Q,non_zeros):
  
  error=0
  
  # 2개의 분해된 행렬 P와 Q.T의 내적으로 예측 R 행렬 생성
  full_pred_matrix = np.dot(P,Q.T)

  # 실제 R 행렬에서 null이 아닌 값의 위치 인덱스를 추출해 실제 R 행렬과 예측 행렬의 RMSE 추출
  x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
  y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
  R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
  full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
  mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
  rmse = np.sqrt(mse)

  return rmse

# %%
# SGD 기반 행렬 분해 수행

## R>0인 행, 열 위치, 값을 non_zeros 리스트에 저장
non_zeros = [(i,j,R[i,j]) for i in range(num_users) for j in range(num_items) if R[i,j]>0]

steps = 1000
learning_rate = 0.01
r_lambda = 0.01

# SGD 기법으로 P와 Q 매트릭스를 계속 업데이트
for step in range(steps):
  for i,j,r in non_zeros:
    # 실제 값과 예측값의 차이인 오류 값 구함
    eij = r - np.dot(P[i,:],Q[j,:].T)
    # Regularization을 반영한 SGD 업데이트 공식 적용
    P[i,:] = P[i,:] + learning_rate*(eij*Q[j,:]-r_lambda*P[i,:])
    Q[j,:] = Q[j,:] + learning_rate*(eij*P[i,:]-r_lambda*Q[j,:])
    rmse = get_rmse(R,P,Q,non_zeros)
    if (step % 50) == 0:
      print('### iteration step : ',step,'rmse : ',rmse)
# Out:
# ### iteration step :  0 rmse :  3.261355059488935
# ### iteration step :  0 rmse :  3.26040057174686
# ### iteration step :  0 rmse :  3.253984404542389
# ### iteration step :  0 rmse :  3.2521583839863624
# ### iteration step :  0 rmse :  3.252335303789125
# ### iteration step :  0 rmse :  3.251072196430487
# ### iteration step :  0 rmse :  3.2492449982564864
# ### iteration step :  0 rmse :  3.247416477570409
# ### iteration step :  0 rmse :  3.241926055455223
# ### iteration step :  0 rmse :  3.2400454107613084
# ### iteration step :  0 rmse :  3.240166740749792
# ### iteration step :  0 rmse :  3.2388050277987723
# ### iteration step :  50 rmse :  0.5003190892212748
# ### iteration step :  50 rmse :  0.5001616291326989
# ### iteration step :  50 rmse :  0.49899601202578087
# ### iteration step :  50 rmse :  0.4988483450145831
# ### iteration step :  50 rmse :  0.49895189256631756
# ### iteration step :  50 rmse :  0.49833236830090993
# ...

# %%
# 분해된 P, Q 함수를 P*Q.T로 예측 행렬을 만들어 출력
pred_matrix = np.dot(P,Q.T)
print('예측 행렬:\n',np.round(pred_matrix,3))
# Out:
# 예측 행렬:
#  [[3.991 0.897 1.306 2.002 1.663]
#  [6.696 4.978 0.979 2.981 1.003]
#  [6.677 0.391 2.987 3.977 3.986]
#  [4.968 2.005 1.006 2.017 1.14 ]]

# %% [markdown]
# 원본 행렬과 비교해 null이 아닌 값은 큰 차이가 나지 않으며, null인 값은 새로운 예측값으로 채워짐
